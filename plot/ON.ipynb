# %% [markdown]
# # Wetterich equation ϕ4 O(N) flow in d = 3

# %% [markdown]
# Using the LPA approximation we solve the Wetterich equation for the $O(N)$ $\phi^4$ thery in $d=3$ dimensions.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
import pandas as pd
from pathlib import Path
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
import h5py
